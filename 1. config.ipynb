# %% [markdown]
# #### Run the cell below to install the required packages for Copilot

# %%
method_map = {
    'first_name': 'first_name',
    'last_name': 'last_name',
    'email': 'email',
    'phone_number': 'phone_number',
    'address': 'address',
    'ssn': 'ssn',
    'passport_number': 'passport_number',
    'street_address': 'street_address',
    'name': 'name',
    'user_name': 'user_name',
    'postalcode': 'postalcode',
    'zipcode': 'zipcode',
    'country_code': 'country_code',
    'date_of_birth': 'date_of_birth'
}
# Out:
# StatementMeta(, 9c1f1d3b-2781-4409-95cf-e2ff9d37a35b, 10, Finished, Available, Finished)

# %%
config = {
    "table_list1": [
        "dim_customer",
        "dim_date",
        "dim_product",
        "dim_store",
        "fact_sales",
        "big_table"
    ],
    "dim_customer": {
        "pii_column_mapping": {
            "CustomerID": "random_int",
            "FirstName": "first_name",
            "LastName": "last_name",
            "Email": "email",
            "PhoneNumber": "phone_number",
            "DateOfBirth": "date_of_birth"
        },
        "location": "Files/synthetic_data/dim_customer_df",
        "file_format": "delta"
    },
    "dim_date": {
        "pii_column_mapping": {},
        "location": "Files/synthetic_data/dim_date_df",
        "file_format": "delta"
    },
    "dim_product": {
        "pii_column_mapping": {},
        "location": "Files/synthetic_data/dim_product_df",
        "file_format": "delta"
    },
    "dim_store": {
        "pii_column_mapping": {
            "ManagerName": "name"
        },
        "location": "Files/synthetic_data/dim_store_df",
        "file_format": "delta"
    },
    "fact_sales": {
        "pii_column_mapping": {
            "CustomerID": "random_int",
            "CustomerEmail": "email"
        },
        "location": "Files/synthetic_data/fact_sales_df",
        "file_format": "delta"
    },
    "big_table":{
        "location": "Tables/customer_details_1b",
        "file_format": "table",
        "pii_column_mapping" : {
            "first_name": "first_name",
            "last_name": "last_name",
            "email": "email",
            "phone_number": "phone_number",
            "address": "address",
            "ssn": "ssn",
            "passport_number": "passport_number",
            "street_address": "street_address",
            "name": "name",
            "user_name": "user_name",
            "postalcode": "postalcode",
            "zipcode": "zipcode",
            "country_code": "country_code",
            "date_of_birth": "date_of_birth"
        }

    }
}
# Out:
# StatementMeta(, 9c1f1d3b-2781-4409-95cf-e2ff9d37a35b, 31, Finished, Available, Finished)
